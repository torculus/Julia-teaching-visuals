# %%
using PyPlot

x = 0:0.01:5;
y = 3 .* x.^2 .* exp.(-x.^3);
plot(x, y, color="green", linewidth=2.0, linestyle="-")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7ff6f8681518>

# %%
x = range(-3, stop=3, length=1000)

z = 1/sqrt(2*pi) * exp.(-1*x.^2/2);
w = 1/sqrt(pi) * exp.(-2*x.^2);
v = 1/sqrt(pi/5) * exp.(-100 * x.^2);

plot(x, z, color="blue", linewidth=2.0, linestyle="-")
plot(x, w, color="green", linewidth=2.0, linestyle="-")
plot(x, v, color="black", linewidth=2.0, linestyle="-")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f07458c82b0>

# %%
x = range(-1, stop=1, length=1000)

n = 5

for i=2:n
    sigma = 1/i^2;
    y = 1/sqrt(2*pi*sigma) * exp.(-1*x.^2/ (sigma^2) );
    plot(x, y, color=(0.01, i/n, i/n), linewidth=2.0, linestyle="-")
end
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
using PyPlot

x = linspace(0,1.2,1000);

y = x.^3 .* (1 - x).^2;

plot(x, y, color="red", linewidth=2.0, linestyle="-")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f78068c6590>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f78066a7d50>

# %%
using PyPlot

x = linspace(-10, 10, 1000)

sigma = 5;
y = 1/sqrt(2*pi*sigma) * exp.(-1*x.^2/ (sigma^2) );
z = zeros(length(x));
plot(x, y, color="blue", linewidth=2.0, linestyle="-")
plot(x, z, color="black", linewidth=2.0, linestyle="-")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8eaae41cd0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f8ea8ba8490>

# %%
using PyPlot

x = linspace(-5, 5, 1000)

sigma = 1;

nu = 1;

y = gamma((nu+1)/2) / ( sqrt(nu*pi) * gamma(nu/2) ) * (1+x.^2/nu).^(-(nu+1)/2);

x2 = x[1:300];

b = bar(x,y, 0.01, color="#ffd68b", align="center", alpha=0.3);

z = zeros(length(x));
plot(x, y, color="orange", linewidth=2.0, linestyle="-")
#plot(x, z, color="black", linewidth=2.0, linestyle="-")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f4d5431e850>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f4d535b2050>

# %%
using PyPlot

x = linspace(-3, 3, 1000)

sigma = 1;
y = 1/sqrt(2*pi*sigma^2) * exp.(-1*x.^2/ (2*sigma^2) );

b = bar(x,y, 0.1, color="#00acfe", align="center", alpha=0.1);

plot(x, y, color="blue", linewidth=2.0, linestyle="-")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f4d507b3950>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f4d49e8ff50>

# %%
using PyPlot

x = linspace(-3, 3, 1000)

sigma = 1;
y = 1/sqrt(2*pi*sigma^2) * exp.(-1*x.^2/ (2*sigma^2) );

N = 100;
z = [y[1:N] ; zeros(1000-N, 1)]

b = bar(x, z, 0.1, color="#00acfe", align="center", alpha=0.1);

length(z)-length(x)

#plot(x, z, color="blue", linewidth=2.0, linestyle="-")
# Out:
# PyError (ccall(@pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, arg, kw)) <type 'exceptions.TypeError'>
# TypeError('only size-1 arrays can be converted to Python scalars',)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.py", line 2648, in bar
#     ret = ax.bar(*args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py", line 1717, in inner
#     return func(ax, *args, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.py", line 2087, in bar
#     label='_nolegend_',
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/patches.py", line 659, in __init__
#     Patch.__init__(self, **kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/patches.py", line 103, in __init__
#     self.set_linewidth(linewidth)
#   File "/usr/local/lib/python2.7/dist-packages/matplotlib/patches.py", line 351, in set_linewidth
#     self._linewidth = float(w)
#
#
# Stacktrace:
# ...

# %%
using PyPlot

x = linspace(0,10,100);
y = 2 + 3*x + 3*randn(length(x),1);
z = 2 + 3*x;
plot(x, y, color="green", linewidth=2.0, linestyle="-")
plot(x, z, color="black", linewidth=2.0, linestyle="--")
title("Stock price with trend")
grid("on")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f97ec0913d0>)

# %%
using PyPlot

x = linspace(0,10,100);
w = 3*randn(length(x),1);
z = 2 + 3*x;
plot(x, w, color="green", linewidth=2.0, linestyle="-")
title("Stock price (detrended)")
grid("on")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fa3fa1e6e50>)

# %%
using PyPlot

x = linspace(-5, 5, 1000)

sigma = 1;

nu = 1;

y = gamma((nu+1)/2) / ( sqrt(nu*pi) * gamma(nu/2) ) * (1+x.^2/nu).^(-(nu+1)/2);

plot(x, y, color="orange", linewidth=2.0, linestyle="-")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f319df705d0>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f319b865f90>

# %%
using PyPlot

k=3;

x = linspace(0,12,1000);

y = 1/(2^(k/2) * gamma(k/2)) * x.^(k/2 - 1) .* exp(-x./2);

plot(x, y, color="purple", linewidth=2.0, linestyle="-")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8fcdc17990>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f8fcda94390>

# %%
using PyPlot

x = range(-3, stop=3, length=1000)

sigma = 1;
y = 1/sqrt(2*pi*sigma^2) * exp.(-1*x.^2/ (2*sigma^2) );

b = bar(x,y, 0.1, color=(0.1, .7, .5), align="center", alpha=0.1);

plot(x, y, color="blue", linewidth=2.0, linestyle="-")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7ff6f66ea978>
